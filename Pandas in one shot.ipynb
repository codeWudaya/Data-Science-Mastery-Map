# %% [markdown]
# # <center>By🎯Udayabhanu Nayak CSE 2024💡</center>

# %% [markdown]
# # <center>📚 Ultimate `Pandas`🐼 Cheat Sheet: Master Data Like a Pro🐼</center>

# %% [markdown]
# ##  Introduction to pandas
#
# ###  used for data processing and Analysis
# ###  install using `!pip install pandas` command
# #### it is a two dimentional tabular data structure with labelled axis (rows and columns)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Create a random data data frame using pandas dataFrame

# %%
row = 3
column = 4
low = 1
high = 10

random_array = np.random.randint(low, high, size=(row, column))
print(random_array)
# Out:
# [[7 5 8 2]
#  [6 3 7 1]
#  [3 5 3 4]]

# %%
index = ["udaya","Follow","me"] # name of index should be same as no of rows
name_of_column=["jan","feb","mar","may"]   # Should be same as no of columns

data = pd.DataFrame(random_array,index=index,columns=name_of_column)
data
# Out:
#         jan  feb  mar  may
# udaya     7    5    8    2
# Follow    6    3    7    1
# me        3    5    3    4

# %% [markdown]
# ## Series

# %%
my_list = [1, 2, 3, 4, 5]
my_series = pd.Series(my_list,index=['a', 'b', 'c', 'd', 'e'])

my_series
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# ### DataFrame

# %%
DFrame ={"name":["udaya","kuku"],
        "age":[22,33]}

dataa = pd.DataFrame(DFrame)
dataa
# Out:
#     name  age
# 0  udaya   22
# 1   kuku   33

# %% [markdown]
# ## Read a dataset
# ### CSV file let's say

# %%
df = pd.read_csv(r"C:\Users\udaya\Desktop\LinkedIn posted projects\Amazon Review.csv")

# %% [markdown]
# ### reading starting 5

# %%
df.head(5)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# ### Reading ending 5 rows

# %%
df.tail(5)
# Out:
#             Id   ProductId          UserId              ProfileName  \
# 568449  568450  B001EO7N10  A28KG5XORO54AY         Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z            pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH  Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                 srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 568449                 Will not do without
# ...

# %%
df.shape
# Out:
# (568454, 10)

# %% [markdown]
# ### To get the name of all the columns and how to rename the name of the columns

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=568454, step=1)

# %%
df = df.rename(columns={'ProfileName':'name','HelpfulnessNumerator':'Helpfull'})

df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'name', 'Helpfull',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %% [markdown]
# ### Statistical description

# %%
df.describe()
# Out:
#                   Id       Helpfull  HelpfulnessDenominator          Score  \
# count  568454.000000  568454.000000            568454.00000  568454.000000
# mean   284227.500000       1.743817                 2.22881       4.183199
# std    164098.679298       7.636513                 8.28974       1.310436
# min         1.000000       0.000000                 0.00000       1.000000
# 25%    142114.250000       0.000000                 0.00000       4.000000
# 50%    284227.500000       0.000000                 1.00000       5.000000
# 75%    426340.750000       2.000000                 2.00000       5.000000
# max    568454.000000     866.000000               923.00000       5.000000
#
#                Time
# count  5.684540e+05
# mean   1.296257e+09
# std    4.804331e+07
# min    9.393408e+08
# 25%    1.271290e+09
# 50%    1.311120e+09
# 75%    1.332720e+09
# max    1.351210e+09

# %% [markdown]
# ### Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   name                    568428 non-null  object
#  4   Helpfull                568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %% [markdown]
# ### Transpose the above

# %%
df.describe().T
# Out:
#                            count          mean           std          min  \
# Id                      568454.0  2.842275e+05  1.640987e+05          1.0
# Helpfull                568454.0  1.743817e+00  7.636513e+00          0.0
# HelpfulnessDenominator  568454.0  2.228810e+00  8.289740e+00          0.0
# Score                   568454.0  4.183199e+00  1.310436e+00          1.0
# Time                    568454.0  1.296257e+09  4.804331e+07  939340800.0
#
#                                  25%           50%           75%           max
# Id                      1.421142e+05  2.842275e+05  4.263408e+05  5.684540e+05
# Helpfull                0.000000e+00  0.000000e+00  2.000000e+00  8.660000e+02
# HelpfulnessDenominator  0.000000e+00  1.000000e+00  2.000000e+00  9.230000e+02
# Score                   4.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# Time                    1.271290e+09  1.311120e+09  1.332720e+09  1.351210e+09

# %% [markdown]
# ### extract out single column

# %%
df['Text'].head(3)
# Out:
# 0    I have bought several of the Vitality canned d...
# 1    Product arrived labeled as Jumbo Salted Peanut...
# 2    This is a confection that has been around a fe...
# Name: Text, dtype: object

# %%
df[['Text']].head(3)
# Out:
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...

# %% [markdown]
# ### To extract out multiple column

# %%
df[['Text','Score']].head(3)
# Out:
#                                                 Text  Score
# 0  I have bought several of the Vitality canned d...      5
# 1  Product arrived labeled as Jumbo Salted Peanut...      1
# 2  This is a confection that has been around a fe...      4

# %% [markdown]
# ### Adding new column

# %%
df["tip_percentage"]=round(df['Score']/df["Helpfull"]*100,2)

# %%
df[['tip_percentage']].head(2)
# Out:
#    tip_percentage
# 0           500.0
# 1             inf

# %%
df.head(1)
# Out:
#    Id   ProductId          UserId        name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian         1
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
#
#                                                 Text  tip_percentage
# 0  I have bought several of the Vitality canned d...           500.0

# %% [markdown]
# ### drop a the column

# %%
df.drop("tip_percentage",axis=1,inplace=True)

# %%
df.head(1)
# Out:
#    Id   ProductId          UserId        name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian         1
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...

# %% [markdown]
# ### drop multiple columns

# %%
df.drop(columns=['Id','ProductId']).head(2)
# Out:
#            UserId        name  Helpfull  HelpfulnessDenominator  Score  \
# 0  A3SGXH7AUHU8GW  delmartian         1                       1      5
# 1  A1D87F6ZCVE5NK      dll pa         0                       0      1
#
#          Time                Summary  \
# 0  1303862400  Good Quality Dog Food
# 1  1346976000      Not as Advertised
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...

# %% [markdown]
# ### set any column as index

# %%
df.set_index('ProductId').head(2)
# Out:
#             Id          UserId        name  Helpfull  HelpfulnessDenominator  \
# ProductId
# B001E4KFG0   1  A3SGXH7AUHU8GW  delmartian         1                       1
# B00813GRG4   2  A1D87F6ZCVE5NK      dll pa         0                       0
#
#             Score        Time                Summary  \
# ProductId
# B001E4KFG0      5  1303862400  Good Quality Dog Food
# B00813GRG4      1  1346976000      Not as Advertised
#
#                                                          Text
# ProductId
# B001E4KFG0  I have bought several of the Vitality canned d...
# B00813GRG4  Product arrived labeled as Jumbo Salted Peanut...

# %% [markdown]
# ### In order to reset index

# %%
df.reset_index().head(2)
# Out:
#    index  Id   ProductId          UserId        name  Helpfull  \
# 0      0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian         1
# 1      1   2  B00813GRG4  A1D87F6ZCVE5NK      dll pa         0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...

# %% [markdown]
# ### To select any specific rows with index postion
# ### iloc[]

# %%
df.iloc[1]
# Out:
# Id                                                                        2
# ProductId                                                        B00813GRG4
# UserId                                                       A1D87F6ZCVE5NK
# name                                                                 dll pa
# Helpfull                                                                  0
# HelpfulnessDenominator                                                    0
# Score                                                                     1
# Time                                                             1346976000
# Summary                                                   Not as Advertised
# Text                      Product arrived labeled as Jumbo Salted Peanut...
# Name: 1, dtype: object

# %%
df.iloc[0]
# Out:
# Id                                                                        1
# ProductId                                                        B001E4KFG0
# UserId                                                       A3SGXH7AUHU8GW
# name                                                             delmartian
# Helpfull                                                                  1
# HelpfulnessDenominator                                                    1
# Score                                                                     5
# Time                                                             1303862400
# Summary                                               Good Quality Dog Food
# Text                      I have bought several of the Vitality canned d...
# Name: 0, dtype: object

# %% [markdown]
# ### For selecting some subsection of the dataframe

# %%
df.iloc[2:4]
# Out:
#    Id   ProductId          UserId                             name  Helpfull  \
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl         3
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
#
#                                                 Text
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...

# %%
df.iloc[2:8:2]
# Out:
#    Id   ProductId          UserId                             name  Helpfull  \
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"         0
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan         0
#
#    HelpfulnessDenominator  Score        Time  \
# 2                       1      4  1219017600
# 4                       0      5  1350777600
# 6                       0      5  1340150400
#
#                                          Summary  \
# 2                          "Delight" says it all
# 4                                    Great taffy
# 6  Great!  Just as good as the expensive brands!
#
#                                                 Text
# 2  This is a confection that has been around a fe...
# 4  Great taffy at a great price.  There was a wid...
# 6  This saltwater taffy had great flavors and was...

# %% [markdown]
# ### loc  vs   iloc

# %%
import pandas as pd

data = {'A': [1, 2, 3],
        'B': [4, 5, 6],
        'C': [7, 8, 9]}

dff = pd.DataFrame(data, index=['X', 'Y', 'Z'])
print(dff.head())
# Selecting a specific row and column using labels
print(dff.loc['Y', 'B'])
# Selecting a specific row and column using integer positions
print(dff.iloc[1 , 2])
# Out:
#    A  B  C
# X  1  4  7
# Y  2  5  8
# Z  3  6  9
# 5
# 8

# %% [markdown]
# ### How to drop the row

# %%
df.drop(2,axis=0).head(3)
# Out:
#    Id   ProductId          UserId        name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian         1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK      dll pa         0
# 3   4  B000UA0QIQ  A395BORC6FGVXV        Karl         3
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 3                       3      2  1307923200         Cough Medicine
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 3  If you are looking for the secret ingredient i...

# %% [markdown]
# ### Conditional filtering

# %%
df[df['Score']>3].head(4)
# Out:
#    Id   ProductId          UserId                             name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian         1
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"         0
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything         0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 2                       1      4  1219017600  "Delight" says it all
# 4                       0      5  1350777600            Great taffy
# 5                       0      4  1342051200             Nice Taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 2  This is a confection that has been around a fe...
# 4  Great taffy at a great price.  There was a wid...
# ...

# %%
df[df['Score']==5].head()
# Out:
#    Id   ProductId          UserId                           name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                     delmartian         1
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T  Michael D. Bigham "M. Wassir"         0
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1              David C. Sullivan         0
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ             Pamela G. Williams         0
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                       R. James         1
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       1      5  1303862400
# 4                       0      5  1350777600
# 6                       0      5  1340150400
# 7                       0      5  1336003200
# 8                       1      5  1322006400
#
#                                          Summary  \
# 0                          Good Quality Dog Food
# 4                                    Great taffy
# 6  Great!  Just as good as the expensive brands!
# ...

# %%
df[(df['Score']>3) & (df['Helpfull']==0)].head()
# Out:
#    Id   ProductId          UserId                           name  Helpfull  \
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T  Michael D. Bigham "M. Wassir"         0
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                 Twoapennything         0
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1              David C. Sullivan         0
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ             Pamela G. Williams         0
# 9  10  B00171APVA  A21BT40VZCCYT4                  Carol A. Reed         0
#
#    HelpfulnessDenominator  Score        Time  \
# 4                       0      5  1350777600
# 5                       0      4  1342051200
# 6                       0      5  1340150400
# 7                       0      5  1336003200
# 9                       0      5  1351209600
#
#                                          Summary  \
# 4                                    Great taffy
# 5                                     Nice Taffy
# 6  Great!  Just as good as the expensive brands!
# ...

# %%
df[(df['Score']>3) | (df['Helpfull']==0)].head()
# Out:
#    Id   ProductId          UserId                             name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian         1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa         0
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"         0
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything         0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 4                       0      5  1350777600            Great taffy
# 5                       0      4  1342051200             Nice Taffy
#
#                                                 Text
# ...

# %% [markdown]
# ### another way of filtering is with isin function

# %%
option = [4,5]

df[df['Score'].isin(option)].head()
# Out:
#    Id   ProductId          UserId                             name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian         1
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"         0
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything         0
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan         0
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       1      5  1303862400
# 2                       1      4  1219017600
# 4                       0      5  1350777600
# 5                       0      4  1342051200
# 6                       0      5  1340150400
#
#                                          Summary  \
# 0                          Good Quality Dog Food
# 2                          "Delight" says it all
# 4                                    Great taffy
# ...

# %% [markdown]
# ## Apply function on a single column

# %%
type('A1UQRSCLF8GW1T')
# Out:
# str

# %%
def last(string):
    return string[-4:]

df['UserId'].apply(last).head()
# Out:
# 0    U8GW
# 1    E5NK
# 2    XAIN
# 3    GVXV
# 4    GW1T
# Name: UserId, dtype: object

# %% [markdown]
# ### Apply function on a multiple column

# %%
# df.apply(lambda x: function(x['col1'], x['col2']), axis=1)

# %% [markdown]
# ### Sorting method in pandas

# %%
df.sort_values(by='Score').head(3)
# Out:
#             Id   ProductId          UserId              name  Helpfull  \
# 117715  117716  B001BM8SS2   AP6Y1EQQU3TRL              Matt         6
# 36571    36572  B004CLCEDE  A2N5V23J2NN855     Amanda Lustig         1
# 427581  427582  B0006U7T1C  A3L9B10V80RNS5  Walter L. Austin         1
#
#         HelpfulnessDenominator  Score        Time                    Summary  \
# 117715                       8      1  1265673600     PACKAGING CONTAINS BPA
# 36571                        2      1  1318204800                    Aweful!
# 427581                       1      1  1283040000  my dogs hate this product
#
#                                                      Text
# 117715  Glass jar lids contain minute amounts of BPA. ...
# 36571   I was looking for a low carb food to substitut...
# 427581  We have to Huskies and an American Eskom, and ...

# %%
df.sort_values(by='Score',ascending=False).head(3)
# Out:
#             Id   ProductId          UserId            name  Helpfull  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW      delmartian         1
# 338694  338695  B001SB3ZHU  A1F4L64W5BREGX    Gary R. Howe         0
# 338711  338712  B001VNFOZ6  A15P7Q1WK4RED0  Terri Fountain         6
#
#         HelpfulnessDenominator  Score        Time                Summary  \
# 0                            1      5  1303862400  Good Quality Dog Food
# 338694                       0      5  1304380800                Bennets
# 338711                       6      5  1293667200           Love 5 Spice
#
#                                                      Text
# 0       I have bought several of the Vitality canned d...
# 338694  Bennets Chili Sauce is the greatest for making...
# 338711  This spice is so hard to find where I live.  S...

# %% [markdown]
# ### Min, max, and their index position

# %%
df['Score'].min()
# Out:
# 1

# %%
df['Score'].max()
# Out:
# 5

# %%
#what is min value of Helpfull and what is its index position


df['Helpfull'].idxmax()
# Out:
# 190733

# %%
#what is min value of Helpfull and what is its index position

df['Helpfull'].idxmin()
# Out:
# 1

# %% [markdown]
# ### Value_counts/unique/nunique/replace/map function

# %%
# quantity of all unique values

df['Score'].value_counts()
# Out:
# Score
# 5    363122
# 4     80655
# 1     52268
# 3     42640
# 2     29769
# Name: count, dtype: int64

# %%
# show all unique value

df['Score'].unique()
# Out:
# array([5, 1, 4, 2, 3], dtype=int64)

# %%
#no of unique value

df['Score'].nunique()
# Out:
# 5

# %%
# replace old with new
# df['column_name'].replace(old_value, new_value)


df['Score'].replace([1,2],[2,1]).head()
# Out:
# 0    5
# 1    2
# 2    4
# 3    1
# 4    5
# Name: Score, dtype: int64

# %%
mymap={1:2,2:1,5:5,4:4}

# %%
df['Score'].map(mymap).head()
# Out:
# 0    5.0
# 1    2.0
# 2    4.0
# 3    1.0
# 4    5.0
# Name: Score, dtype: float64

# %% [markdown]
# ### Treatment of duplicate values

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 568449    False
# 568450    False
# 568451    False
# 568452    False
# 568453    False
# Length: 568454, dtype: bool

# %%
df.drop_duplicates().head(5)
# Out:
#    Id   ProductId          UserId                             name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian         1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa         0
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl         3
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"         0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text
# ...

# %% [markdown]
# ### nlargest and nsmallest

# %%
#show me the 5 largest tip

df.nlargest(5,'Score')
# Out:
#    Id   ProductId          UserId                           name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                     delmartian         1
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T  Michael D. Bigham "M. Wassir"         0
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1              David C. Sullivan         0
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ             Pamela G. Williams         0
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                       R. James         1
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       1      5  1303862400
# 4                       0      5  1350777600
# 6                       0      5  1340150400
# 7                       0      5  1336003200
# 8                       1      5  1322006400
#
#                                          Summary  \
# 0                          Good Quality Dog Food
# 4                                    Great taffy
# 6  Great!  Just as good as the expensive brands!
# ...

# %%
#show me the 5 smallest tip

df.nsmallest(5,'Score')
# Out:
#     Id   ProductId          UserId           name  Helpfull  \
# 1    2  B00813GRG4  A1D87F6ZCVE5NK         dll pa         0
# 12  13  B0009XLVG0   A327PCT23YH90             LT         1
# 26  27  B001GVISJM  A3RXAU2N8KV45G         lady21         0
# 50  51  B001EO5QW8  A108P30XVUFKXY      Roberto A         0
# 62  63  B001EO5TPM  A1E09XGZUR78C6  gary sturrock         2
#
#     HelpfulnessDenominator  Score        Time  \
# 1                        0      1  1346976000
# 12                       1      1  1339545600
# 26                       1      1  1332633600
# 50                       7      1  1203379200
# 62                       2      1  1215302400
#
#                                  Summary  \
# 1                      Not as Advertised
# 12  My Cats Are Not Fans of the New Food
# 26                       Nasty No flavor
# 50                         Don't like it
# 62                        stale product.
#
#                                                  Text
# ...

# %% [markdown]
# ### Random sample of the dataset by the number or percentage

# %%
# any random 5 sample

df.sample(5)
# Out:
#             Id   ProductId          UserId                   name  Helpfull  \
# 373734  373735  B004WTHCO2  A19V0IMEE6W8JL                Mariana         0
# 312441  312442  B0029Y4PM4  A1926ZO7KQDQJO                  Kathy         2
# 383321  383322  B0024NUM8G  A1LY3EAJ4YHVM7                 Vox416         0
# 52259    52260  B000H27PAO   AP5ZNBCXRU7QW  T. J. "Computer Geek"         0
# 516729  516730  B001QX2IH8  A1TLRLA5V4TGC8                   MMay         9
#
#         HelpfulnessDenominator  Score        Time  \
# 373734                       0      5  1337126400
# 312441                       2      3  1315872000
# 383321                       0      5  1343260800
# 52259                        0      5  1341014400
# 516729                      11      1  1304553600
#
#                              Summary  \
# 373734                incredible!!!!
# 312441  Moravian Meyer Lemon Cookies
# 383321                   Great gift!
# 52259               Love This Stuff!
# ...

# %%
# 1 percent sample

df.sample(frac=0.01)
# Out:
#             Id   ProductId          UserId                               name  \
# 43825    43826  B001EQ5JLE  A3Q5RK58BE1BY6          T. Marsh "Terrey Bassett"
# 120035  120036  B001E5E3D0  A13CNQGT2YCQE2  typeA_feedingOs "typeA_feedingOs"
# 189942  189943  B0012JMSG2  A2UYH5PSDYSXXI                            Mermama
# 537904  537905  B003BGRUPI  A1L7FMN8DJEN4E   Evelyn Goodman "psychotherapist"
# 357585  357586  B00806NK62  A206FREHZ6ZBIH                           Parisian
# ...        ...         ...             ...                                ...
# 139055  139056  B0041CIR62  A13WOT3RSXKRD5                                 LD
# 504376  504377  B007I7YZJK  A235NA61RC6YC1                      George Dionne
# 54340    54341  B001EO5YCA   A7EK88GF8N40F                   Nicole S. Urdang
# 368788  368789  B001D0DMMY   AAJSIP9A8OY5Y                       Dynamic Dave
# 53948    53949  B000AYDH2Y  A33REC3J2JU2EL                        D. Figueroa
#
# ...

# %% [markdown]
# ## How to handle missing data
# * real world data will ofter be missing data for variety of reason
# * many machine learning models and statistical methods cant work with missing data in such case we
# * need to decide what to do with missing data
# ### when reading missing values pandas will display them as NaN values
# #### Option for missing data
# * keep it
# * remove it
# * replace it
# #### Keeping the missing data
# * pros --> Does not manipulate or change the true data
# * Cons --> Many method or model do not support NaN values
# #### Dropping or Removing the missing data
# * pros --> easy/ can be based on rules
# * Cons --> chance of lossing lot of data or usefull information can also be loss
# #### Filling the missing data
# * pros --> potential to save lot of data for use of training a model
# * Cons --> Hardest to do and somewhat arbitrary --> potentail to lead false conclusion

# %%
df.head(2)
# Out:
#    Id   ProductId          UserId        name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian         1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK      dll pa         0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...

# %% [markdown]
# ### isnull

# %%
# wherever there is missing value it shows true

df.isnull()
# Out:
#            Id  ProductId  UserId   name  Helpfull  HelpfulnessDenominator  \
# 0       False      False   False  False     False                   False
# 1       False      False   False  False     False                   False
# 2       False      False   False  False     False                   False
# 3       False      False   False  False     False                   False
# 4       False      False   False  False     False                   False
# ...       ...        ...     ...    ...       ...                     ...
# 568449  False      False   False  False     False                   False
# 568450  False      False   False  False     False                   False
# 568451  False      False   False  False     False                   False
# 568452  False      False   False  False     False                   False
# 568453  False      False   False  False     False                   False
#
#         Score   Time  Summary   Text
# 0       False  False    False  False
# ...

# %%
df[df['name'].isnull()]
# Out:
#             Id   ProductId          UserId name  Helpfull  \
# 10616    10617  B002DHN956  A1LSYR30XW7CFT  NaN         1
# 25509    25510  B000LKZB4Y  A36BVYD0NT7Z0F  NaN         0
# 38874    38875  B000AYDGZ2  A36BVYD0NT7Z0F  NaN         2
# 47923    47924  B004SRH2B6  A2DEHJJIEAPPBF  NaN         0
# 49800    49801  B000CRHQN0  A2LYFY32LXQDON  NaN         0
# 67077    67078  B0006348H2  A2P0P67Y55SNOX  NaN         1
# 106550  106551  B001EQ5DG0  A1P500QXEG3IUZ  NaN         0
# 121819  121820  B006N3I2SK  A34F9B57SYQ5XR  NaN         0
# 125452  125453  B001EO6ESS  A34F9B57SYQ5XR  NaN         0
# 137613  137614  B000CQE3HS   AGT3BYX5P9SLH  NaN         0
# 163191  163192  B000CQID1A   AGT3BYX5P9SLH  NaN         0
# 172462  172463  B001FA1L9I   AC9U70TRGPDGJ  NaN         0
# 211846  211847  B000CNB4LE  A2DEHJJIEAPPBF  NaN         0
# 268648  268649  B004SRFYMK  A2DEHJJIEAPPBF  NaN         0
# 297275  297276  B007OXJM6E  A29D7XVSBCLFLD  NaN         0
# ...

# %% [markdown]
# ### notnull

# %%
# reverse of isnull will indicate by false wherever there is missing value

df.notnull().head(5)
# Out:
#      Id  ProductId  UserId  name  Helpfull  HelpfulnessDenominator  Score  \
# 0  True       True    True  True      True                    True   True
# 1  True       True    True  True      True                    True   True
# 2  True       True    True  True      True                    True   True
# 3  True       True    True  True      True                    True   True
# 4  True       True    True  True      True                    True   True
#
#    Time  Summary  Text
# 0  True     True  True
# 1  True     True  True
# 2  True     True  True
# 3  True     True  True
# 4  True     True  True

# %%
df[df['name'].notnull()].head(4)
# Out:
#    Id   ProductId          UserId                             name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian         1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa         0
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl         3
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# ...

# %%
df[(df['HelpfulnessDenominator'].isnull()) & (df['HelpfulnessDenominator'].notnull())]
# Out:
# Empty DataFrame
# Columns: [Id, ProductId, UserId, name, Helpfull, HelpfulnessDenominator, Score, Time, Summary, Text]
# Index: []

# %% [markdown]
# ## Dropping

# %%
# this will remove the row which contail even one missing value 

df.dropna().head(4)
# Out:
#    Id   ProductId          UserId                             name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian         1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa         0
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl         3
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# ...

# %%
# to prevent from this we can use threshold==> it means only drop the row if it contain 1

df.dropna(thresh=1).head(3)
# Out:
#    Id   ProductId          UserId                             name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian         1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa         0
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...

# %% [markdown]
# ### Filling Na values

# %%
df.fillna(df['Score'].mean()).head(3)
# Out:
#    Id   ProductId          UserId                             name  Helpfull  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian         1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa         0
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"         1
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...

# %% [markdown]
# ### Group By operation on Pandas
#
#
# * A groupby() operation allows us to examine data per category basis
# * group by is applicable on either categorical or discrete(when the column contain numerical column)
# column

# %% [markdown]
# ### Combining dataframes - Concatenation

# %%
data_one={"A":["A0","A1","A2","A3"],"B":["B0","B1","B2","B3"]}
df1=pd.DataFrame(data_one)
data_Two={"C":["C0","C1","C2","C3"],"D":["D0","D1","D2","D3"]}
df2=pd.DataFrame(data_Two)

pd.concat([df1, df2], axis=0)
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
pd.concat([df1, df2], axis=1)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %% [markdown]
# ## Combining Dataframe --> Merging
# * this is analogous to Join in sql
# * the merge method take key argument labelled how
# * there are three way of merging how= inner,outer , left or right

# %%
registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
logins = pd.DataFrame({'log_id':[1,2,3,4],'name':['Xavier','Andrew','Yolanda','Bobo']})

# %%
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
pd.merge(registrations,logins,how="inner",on="name")
# Out:
#    reg_id    name  log_id
# 0       1  Andrew       2
# 1       2    Bobo       4

# %%
pd.merge(registrations,logins,how="left",on="name")
# Out:
#    reg_id    name  log_id
# 0       1  Andrew     2.0
# 1       2    Bobo     4.0
# 2       3  Claire     NaN
# 3       4   David     NaN

# %%
pd.merge(registrations,logins,how="right",on="name")
# Out:
#    reg_id     name  log_id
# 0     NaN   Xavier       1
# 1     1.0   Andrew       2
# 2     NaN  Yolanda       3
# 3     2.0     Bobo       4

# %%
pd.merge(registrations,logins,how="outer",on="name")
# Out:
#    reg_id     name  log_id
# 0     1.0   Andrew     2.0
# 1     2.0     Bobo     4.0
# 2     3.0   Claire     NaN
# 3     4.0    David     NaN
# 4     NaN   Xavier     1.0
# 5     NaN  Yolanda     3.0

# %% [markdown]
# ### Text method on string data

# %%
#split
email="udaya@nayak@gmail.com"
email.split("@")
# Out:
# ['udaya', 'nayak', 'gmail.com']

# %%
name="Udaya"
name.isdigit()
# Out:
# False

# %%
name="1"
name.isdigit()
# Out:
# True

# %%
names=pd.Series(["Udaya","Bhanu","Rohit",'Mansu'])
names
# Out:
# 0    Udaya
# 1    Bhanu
# 2    Rohit
# 3    Mansu
# dtype: object

# %%
names.str.upper()
# Out:
# 0    UDAYA
# 1    BHANU
# 2    ROHIT
# 3    MANSU
# dtype: object

# %%
names.str.capitalize()
# Out:
# 0    Udaya
# 1    Bhanu
# 2    Rohit
# 3    Mansu
# dtype: object

# %%
names.str.lower()
# Out:
# 0    udaya
# 1    bhanu
# 2    rohit
# 3    mansu
# dtype: object

# %% [markdown]
# ### How to clean the data

# %%
series = pd.Series(["  Udaya","Bhanu  ","Rohit",' Mansu '])

# %%
series
# Out:
# 0      Udaya
# 1    Bhanu
# 2      Rohit
# 3     Mansu
# dtype: object

# %%
series.str.strip().str.capitalize()
# Out:
# 0    Udaya
# 1    Bhanu
# 2    Rohit
# 3    Mansu
# dtype: object

# %% [markdown]
# # Xtra

# %% [raw]
# Loading Data:
#
# pd.read_csv('filename.csv'): Load data from a CSV file.
# pd.read_excel('filename.xlsx'): Load data from an Excel file.
# pd.read_json('filename.json'): Load data from a JSON file.
# pd.read_sql('query', connection_object): Load data from an SQL query.
# Data Exploration:
#
# df.head(): View the first few rows of the DataFrame.
# df.tail(): View the last few rows of the DataFrame.
# df.shape: Get the dimensions of the DataFrame.
# df.info(): Get a concise summary of the DataFrame.
# df.describe(): Get statistical information about the DataFrame.
# Data Manipulation:
#
# df['column_name']: Select a single column.
# df[['column1', 'column2']]: Select multiple columns.
# df.loc[row_indexer, column_indexer]: Access a group of rows and columns by labels.
# df.iloc[row_indexer, column_indexer]: Access a group of rows and columns by integer position.
# df.drop(['column_name'], axis=1): Drop a column.
# df.rename(columns={'old_name': 'new_name'}): Rename columns.
# df['new_column'] = df['column1'] + df['column2']: Create a new column based on existing columns.
# Data Cleaning:
#
# df.isnull(): Check for missing values.
# df.dropna(): Drop rows with missing values.
# df.fillna(value): Fill missing values with a specified value.
# df.drop_duplicates(): Remove duplicate rows.
# df.replace(to_replace, value): Replace values in the DataFrame.
# Data Filtering:
#
# df[df['column'] > value]: Filter rows based on a condition.
# df.query('column > value'): Filter rows using a query expression.
# Grouping and Aggregation:
#
# df.groupby('column').mean(): Group data by a column and calculate the mean.
# df.groupby('column').agg({'column2': 'sum'}): Group data and perform custom aggregation.
# df.pivot_table(index='column1', values='column2', aggfunc=np.sum): Create a pivot table.
# Data Visualization:
#
# df.plot(kind='...', x='column1', y='column2'): Plot data using Matplotlib.
# df['column'].plot.hist(): Plot a histogram.
# sns.heatmap(df.corr(), annot=True, cmap='coolwarm'): Plot a heatmap of correlation matrix using Seaborn.
# Exporting Data:
#
# df.to_csv('filename.csv', index=False): Export data to a CSV file.
# df.to_excel('filename.xlsx', index=False): Export data to an Excel file.
# df.to_json('filename.json', orient='records'): Export data to a JSON file.

# %% [markdown]
# # <center>🎯Thank you if it helped you a little 😊</center>

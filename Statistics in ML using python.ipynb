# %% [markdown]
# # <center>By 🎯Udayabhanu Nayak CSE Grad 2024</center>

# %% [markdown]
# ## Statistics Practical Implementation 📉

# %% [markdown]
# ### Measure Of Central Tendency
#
# 1. Mean
# 2. Median
# 3. Mode

# %%
ages=[23,24,32,45,12,43,67,45,32,56,32,120]

# %% [markdown]
# ### Import

# %%
import numpy as np
import statistics

# %% [markdown]
# ### mean
# Used when outlier is no there , other wise it is affected by outliers

# %%
print(np.mean(ages))
# Out:
# 44.25

# %%
print(statistics.mean(ages))
# Out:
# 44.25

# %% [markdown]
# ### Median
# To deal with outliers

# %%
print(np.median(ages))
# Out:
# 37.5

# %%
print(statistics.median(ages))
# Out:
# 37.5

# %% [markdown]
# ### Mode
# Used when to identify a category to fill the data in as it uses frequency.

# %%
statistics.mode(ages)
# Out:
# 32

# %% [markdown]
# ## Boxplot

# %%
import seaborn as sns
sns.boxplot(ages)
# Out:
# <Axes: >

# %% [markdown]
# ## Number Summary

# %%
import numpy as np

# %%
q1,q3=np.percentile(ages,[25,75])

# %%
print(q1,q3)
# Out:
# 30.0 47.75

# %% [markdown]
# ## Let's check outlier[Lower Fence- Higher fence]

# %%
IQR=q3-q1
lower_fence=q1-1.5*(IQR)
higher_fence=q3+1.5*(IQR)
print(lower_fence,higher_fence)
# Out:
# 3.375 74.375

# %% [markdown]
# N.B : so in this range (3.375 , 74.375) all values are good to consider , value exceed the range means outlier eg. 120

# %% [markdown]
# ## Measure Of Dispersion
#
# 1. Variance
# 2. Standard Deviation

# %% [markdown]
# sample variance

# %%
statistics.variance(ages)
# Out:
# 795.2954545454545

# %% [markdown]
# population variance

# %%
statistics.pvariance(ages)
# Out:
# 729.0208333333334

# %%
np.var(ages,axis=0)
# Out:
# 729.0208333333334

# %% [markdown]
#  Both gives different variance as `statistics.variance` calculates `sample variance` and `np.var` calculates `population variance`

# %% [markdown]
# #### Manually calculate variance

# %%
def variance(data):
    n=len(ages)
  ## mean of the data
    mean=sum(data)/n
  ## variance
    deviation=[(x - mean) ** 2 for x in data]
    variance=sum(deviation)/(n-1)
    return variance

# %%
variance(ages)
# Out:
# 795.2954545454545

# %%
def variance(data,dof=0):
    n=len(ages)
    ## mean of the data
    mean=sum(data)/n
    ## variance
    deviation=[(x - mean) ** 2 for x in data]
    variance=sum(deviation)/(n-dof)
    return variance

# %%
variance(ages,dof=1)
# Out:
# 795.2954545454545

# %% [markdown]
# ## Standard Deviation

# %%
import math
math.sqrt(statistics.pvariance(ages))
# Out:
# 27.000385799712813

# %% [markdown]
# ## Histograms And PDF

# %%
import seaborn as sns
sns.histplot(ages)
# Out:
# <Axes: ylabel='Count'>

# %%
### Kernel density estimater
### PDF

sns.histplot(ages,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### On iris dataset

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df['sepal_length'],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# #### Gaussian / Normal distribution

# %%
sns.histplot(df['sepal_width'],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df['petal_length'],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df['petal_width'],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %% [markdown]
# #### create a normal distributed data

# %%
s=np.random.normal(0.5,0.2,1000)

# %%
s
# Out:
# array([ 0.23827335,  0.66056163,  0.74232696,  0.67319033,  0.34861719,
#         0.69317885,  0.4640027 ,  0.61998003,  0.39971382, -0.02008048,
#         0.73698106,  0.7069826 ,  0.65277738,  0.57237388,  0.4941129 ,
#         0.20523609,  0.6693801 ,  0.50723335,  0.03873224,  0.55544328,
#         0.10115847,  0.21585706,  0.71136682,  0.31560936,  0.38112931,
#         0.4660875 ,  0.8262286 ,  0.45849306,  0.11901987,  0.14864948,
#         0.4890154 ,  0.13882865,  0.87670093,  0.69774077,  0.45753076,
#         0.59410748,  0.71284481,  0.20370898,  0.70687184,  0.70422663,
#         0.57575278,  0.10083459,  0.67955481,  0.40232361,  0.83712288,
#         0.44339371,  0.52462406,  0.44518916,  0.63195295,  0.43510361,
#         0.84923669,  0.73138692,  0.80533195,  0.40142403,  0.29800992,
#         0.53245766,  0.50105298,  0.9234668 ,  0.38965621,  0.3913594 ,
#        -0.12851213,  0.72180242,  0.55340292,  0.81479094,  0.22411046,
#         0.59966365,  0.64849896,  0.61766732,  0.23334581,  0.49452869,
#         0.36826561,  0.76829722,  0.43643611,  0.48649243,  0.31575935,
#         0.42404111,  0.38346984,  0.38025355,  0.73854536,  0.4857704 ,
#         0.55246169,  0.5273949 ,  0.51916699,  0.48361052,  0.24321018,
#         0.2068451 ,  0.33470549,  0.21940951,  0.53942625,  0.8353439 ,
#         0.64737244,  0.52532918,  0.73192572,  0.8407171 ,  0.30498867,
#         0.28256163,  0.4984336 ,  0.72893851,  0.57510502,  0.24655159,
#         0.34959998,  0.58138156,  0.5639209 ,  0.60809416,  0.0226194 ,
#         0.37542325,  0.46173446,  0.65207063,  0.211771  ,  0.57364345,
#         0.59928753,  0.82824434,  0.47515434,  0.65850356,  0.24808253,
#         0.62755962,  1.13060349,  0.86003219,  0.44943796,  0.59768633,
#         0.18943702,  0.3996053 ,  0.46693415,  0.25360461,  0.72068019,
#         0.56508404,  0.36175091,  0.35216934,  0.39826641,  0.75233897,
#         0.59471102,  0.47967238,  0.42456447,  0.49218019,  0.13525141,
#         0.24483116,  0.5347434 ,  0.91655724,  0.62510718,  0.20429167,
#         0.57233416, -0.01063213,  0.39383188,  0.44060467,  0.8490167 ,
#         0.29013016,  0.54797106,  0.69349546,  0.27559124,  0.44190872,
#         0.49308351,  0.51876497,  0.56563809,  0.39990354,  0.54940921,
#         0.46562819,  0.50959101,  0.43782442,  0.15978346,  0.50444265,
#         0.36573517,  0.53319322,  0.55411041,  0.56827419,  0.6675733 ,
#         0.76462042,  0.57273608,  0.68113311,  0.67245611,  0.38171817,
#         0.53308742,  0.46968702,  0.52434311,  0.83076958,  0.73947906,
#         0.49396954,  0.37399843,  0.45360961,  0.44540899,  0.58654024,
#         0.27334008,  0.43450493,  0.40717419,  0.82595916,  0.66748668,
#         0.44693132,  0.89451276,  0.70938702,  0.27751372,  0.4609901 ,
#         0.22942828,  0.63389963,  0.13400677,  0.40477966,  0.19271789,
#         0.48688391,  0.49725145,  0.5705023 ,  0.40199131,  0.32645313,
#         0.75290905,  0.52866976,  0.45563633,  0.53994087,  0.35702885,
#         0.36316085,  0.35008498,  0.8617652 ,  0.73531793,  0.60962966,
#         0.3972566 ,  0.56957724,  0.35985238,  0.73404012,  0.45523042,
#         0.2012284 ,  0.2471867 ,  0.47972743,  0.35964044,  0.85225834,
#         0.54795075,  0.41828996,  0.47903913,  0.33590784,  0.15492298,
#         0.53944666,  0.13290227,  0.68610938,  0.47031915,  0.26720929,
#         0.12840208,  0.3313957 ,  0.6241751 ,  0.30105514,  0.40832991,
#         0.44820567,  0.47552406,  0.79806929,  0.63675955,  0.79455127,
#         0.36866759,  0.47022132,  0.69030485,  0.48986233,  0.32207494,
#         0.33773895,  0.69187754,  0.55222374,  0.42764961,  0.82051722,
#         0.41881149,  0.64240667,  0.48649444,  0.24891547,  0.72580911,
#         0.52775133,  0.50404507,  0.51007878,  0.53911593,  0.43511772,
#         0.27499112,  0.51691938,  0.5155864 ,  0.56654828,  0.40496087,
#         0.28499774,  0.32925952,  0.67814816,  0.24624352,  0.30734633,
#         0.38960796,  0.72979317,  0.60601947,  0.53139547,  0.96650436,
#         0.25558859,  0.60389673,  0.43187391,  0.49220948,  0.47606384,
#         0.71672377,  0.6808903 ,  0.4894019 ,  0.52543788,  0.55365289,
#         0.6083051 ,  0.3082106 ,  0.47399432,  0.93602663,  0.65666769,
#         0.56888838,  0.7518945 ,  0.09388553,  0.312145  ,  0.61357322,
#         0.31665283,  0.4038192 ,  0.80443879,  0.26250383,  0.40143018,
#         0.29554899,  0.65490587,  0.68147878,  0.13020702,  0.68032493,
#         0.36400377,  0.52195814,  0.78197065,  0.59205773,  0.55264554,
#         0.58235408,  0.3243783 ,  0.18426922,  0.10550362,  0.55090736,
#         0.47271343,  0.73899992,  0.6182154 ,  0.50514905,  0.47090348,
#         0.53894345,  0.56583858,  0.4382214 ,  0.17565598,  0.63869282,
#         0.34899296,  0.73267597,  0.78043069,  0.63923084,  0.59404955,
#         0.41509959,  0.58051542,  0.6807998 ,  0.8180958 ,  0.7851811 ,
#         0.29576119,  0.2453874 ,  0.38023519,  0.47072218,  0.30947875,
#         0.76260296,  0.22844276,  0.58817141,  0.53287147,  0.19586119,
#         0.4157287 ,  0.85333079,  0.4063053 ,  0.5555531 ,  0.60750197,
#         0.42869253,  0.60601447,  0.65929379,  0.58938365,  0.28554431,
#         0.60028006,  0.79610336,  0.31748234,  0.11508149,  0.74473452,
#         0.57325385,  0.36305736,  0.43530184,  0.1923496 ,  0.85809734,
#         0.59984652,  0.20174231,  0.56635587,  0.40887301,  0.20754978,
#         0.23497414,  0.46386962,  0.30178859,  0.51688667,  0.20781202,
#         0.56428511,  0.56079699,  0.6124119 ,  0.6365287 ,  0.1806256 ,
#         0.25575067,  0.43200754,  0.54832867,  0.64592937,  0.46172332,
#         0.38568843,  0.43464989,  0.40976754,  0.32533246,  0.43433777,
#         0.58570323,  0.35830513,  0.5447272 ,  0.64187025,  0.52704334,
#         0.73982382,  0.11726647,  0.39846851,  0.60261105,  0.56134211,
#         0.23263719,  0.45673415,  0.20466553,  0.5856378 ,  0.63345492,
#         0.19954952,  0.23152667,  0.51134587,  0.64286079,  0.62034577,
#         0.56414663,  0.25302394,  0.65492205, -0.10459743,  0.47259036,
#         0.4330371 ,  0.70599164,  0.40258469,  0.26709341,  0.66414155,
#         0.34393676,  0.33081892,  0.64827205,  0.3496093 ,  0.36848961,
#         0.69873386,  0.52099141,  0.45123154,  0.66043449,  0.24146205,
#         0.59781891,  0.72350963,  0.30966979,  0.67709664,  0.85249781,
#         0.5608393 ,  0.18054093,  0.13364765,  0.25421746,  0.352289  ,
#         0.36795934,  0.46918502,  0.51389587,  0.34212321,  0.55357005,
#         0.80538755,  0.33950702,  0.4937754 ,  0.75668231,  0.68716888,
#         0.56623893,  0.43655801,  0.07528662,  0.12388909,  0.69246935,
#         0.51939377,  0.70722588,  0.41655368,  0.51522433,  0.48672752,
#         0.66246383,  0.7005095 ,  0.47890742,  0.98595472,  0.80894462,
#         0.10207676,  0.87152272,  0.71791915,  0.43972796,  0.24064468,
#         0.9668744 ,  0.68806923,  0.68556329,  0.36410939,  0.48975515,
#         0.33301985,  0.70807124,  0.51334025,  0.21849213,  0.25350892,
#         0.18679496,  0.31393155,  0.79550086,  0.37933304,  0.45141314,
#         0.43127213,  0.28875495,  0.40791923,  0.50144372,  0.32548767,
#         0.64488101,  0.72593313,  0.45429438,  0.3050129 ,  0.34637603,
#         0.38577424,  0.3774737 ,  0.76117541,  0.40462231,  0.50704353,
#         0.84871063,  0.41386567,  0.6134772 ,  0.64558789,  0.76228603,
#         0.73252684,  0.58576244,  0.00394707,  0.40188027,  0.68861277,
#         0.17379025,  0.48208419,  0.51654851,  0.34244041,  0.40033076,
#         0.49116851,  0.44925841,  0.81621005,  0.47016581,  0.37132435,
#         0.28554375,  0.59884362,  0.58303436,  0.63296245,  0.8845491 ,
#         0.55549847,  0.33497908,  0.06462041,  0.49154117,  0.70021365,
#         0.38117876,  0.65234285,  0.80443871,  0.63380701,  0.44292027,
#         0.55558476,  0.5507297 ,  0.3958672 ,  0.27455987,  0.61949561,
#         0.63005327,  0.43144889,  0.28832619,  0.62411437,  0.53844211,
#         0.63035771,  0.41553794,  0.54058708,  0.44676615,  0.32325732,
#         0.55632678,  0.54413906,  0.67391275,  0.63882811,  0.35164546,
#         0.31820827,  0.32631401,  0.34482901,  0.10864395,  0.72976484,
#         0.710669  ,  0.36154929,  0.65976721,  0.41684377,  0.55235429,
#         0.70586347,  0.35838487,  0.35732736,  0.59516715,  0.31942149,
#         0.45727033,  0.35250786,  0.51620391,  0.45768217,  0.83773813,
#         0.46552321,  0.40934134, -0.2160037 ,  0.6758167 ,  0.45021859,
#         0.2483298 ,  0.40883869,  0.79115115,  0.3913156 ,  0.27546707,
#         0.32687016,  0.77059096,  0.45525098,  0.86509421,  0.38846964,
#         0.45717053,  0.69470766,  0.59546965,  0.31505748,  0.46229188,
#         0.49150718,  0.34128542,  0.58555375,  0.78044038,  0.39149063,
#         0.43214077,  0.3118901 ,  0.5979143 ,  0.35943667,  0.59764577,
#         0.46968144,  0.74166893,  0.56994622,  0.40433391,  0.62553684,
#         0.24684212,  0.95437544,  0.68513728,  1.05215898,  0.58410667,
#         0.66983892,  0.47519376,  0.45028502,  0.56946852,  0.4246842 ,
#         0.61044141,  0.58240549,  0.61860186,  0.21220737,  0.48476012,
#         0.51465854,  0.01624574,  0.40964842,  0.78168135,  0.89747097,
#         0.24877869,  0.52619792,  0.56230281,  0.78935822,  0.68865404,
#         0.63549385,  0.64161027,  0.77881043,  0.540314  ,  0.41098371,
#         0.34874307,  0.82135491,  0.38871589,  0.75984106,  0.60860674,
#         0.78902099,  0.41336795,  0.23107837,  1.11171178,  0.60345024,
#         0.52833703,  0.32012291,  0.44827963,  0.12258926,  0.26617178,
#         0.50367422,  0.26958837,  0.38900072,  0.38763084,  0.5535422 ,
#         0.1182159 ,  0.11699334,  0.56782274,  0.29789229,  0.56424838,
#         0.89650412,  0.66834988,  0.2044707 ,  0.74953492,  0.45478152,
#         0.51402732,  0.63359122,  0.64907879,  0.44159075,  0.38742451,
#         0.68533448,  0.44547765,  0.61421067,  0.22127411,  0.39878142,
#         0.55886276,  0.26006316,  0.86300072,  0.75224034,  0.78509454,
#         0.63674141,  0.40734575,  0.5083001 ,  0.5375409 ,  0.33997586,
#         0.58037673,  0.38763182,  0.52190588,  0.55864791,  0.41967981,
#         0.4912828 ,  0.53844595,  0.22381562,  0.8822251 ,  0.37615113,
#         0.71564946,  1.22217785,  0.7384942 ,  0.67537735,  0.31852391,
#         0.74714682,  0.27768553,  0.20037174,  0.50410723,  0.52639557,
#         0.87648237,  0.60391854,  0.46126873,  0.47563671,  0.77332667,
#         0.28187117,  0.40780347,  0.7371053 ,  0.59627875,  0.32423596,
#         0.52676079,  0.66112984,  0.36677459,  0.3624524 ,  0.63444852,
#         1.14844402,  0.56941569,  0.51691889,  0.51578113,  0.63055133,
#         0.54024652,  0.39221429,  0.56365261,  0.36191276,  0.40915312,
#         0.25824099,  0.5046876 ,  0.66487428,  0.75074836,  0.56266405,
#         0.54932048,  0.27628598,  0.43618102,  0.21805482,  0.54479791,
#         0.38748063,  0.36785668,  0.9087171 ,  0.42874528,  0.42792145,
#         0.58990512,  0.45938153,  0.71787515,  0.67536675,  0.56392123,
#         0.32041528,  0.34951575,  0.18735212,  0.80909315,  0.52691154,
#         0.65584633,  0.50328025,  0.63675331,  0.5700975 ,  0.47052002,
#         0.32500595,  0.68413584,  0.06034731,  0.46743906,  0.53037921,
#         0.59706467, -0.01001768,  0.29609064,  0.45477013,  0.53442787,
#         0.2644805 ,  0.48025914,  0.20351936,  0.54042671,  0.65813942,
#         0.44528346,  0.38138696,  0.47223757,  0.26861282,  0.52467429,
#         0.27439107,  0.7466383 ,  0.12590966,  0.58232083,  0.36425764,
#         0.665452  ,  0.37841483,  0.21126729,  0.22543784,  0.82602649,
#         0.36117536,  0.7181893 ,  0.33893955,  0.69191939,  0.65600739,
#         0.44651397,  0.63530203,  0.27625182,  0.34745144,  0.52700534,
#         0.46703785,  0.29835674,  0.35982713,  0.34055001,  0.21967319,
#         0.75510331,  0.5716756 ,  0.68649577,  0.48407489,  0.51534702,
#         0.47965894,  0.28491711,  0.29690363,  0.63229877,  0.43826453,
#         0.06600466,  0.39195968,  0.51272588,  0.73042937,  0.5316637 ,
#         0.73059502,  0.44089389,  0.57029662,  0.39902142,  0.24612793,
#         0.39462524,  0.63896109,  0.528817  ,  0.509357  ,  0.53991935,
#         0.48337414,  0.78300739,  0.59108256,  0.46561656,  0.3545659 ,
#         0.40950809,  0.5812416 ,  0.37184809,  0.31775997,  0.67007326,
#         0.35562845,  0.1760194 ,  0.39729435,  0.26567089,  0.66273968,
#         0.43451515,  0.57690576,  0.31501919,  0.35938257,  0.57251986,
#         0.42077737,  0.60529175,  0.60089082,  0.5956026 ,  0.54200767,
#         0.7112391 ,  0.33716268,  0.40677566,  0.67579522,  0.6235373 ,
#         0.37127258,  0.30238167,  0.35582427,  0.20612907,  0.53447457,
#         0.67856035,  0.43703695,  0.25529619,  0.88529984,  0.62360779,
#         0.64551776,  0.8506252 ,  0.60882054,  0.74421809,  0.12850588,
#         0.59340976,  0.29876582,  0.4225675 ,  0.48800936,  0.55956471,
#         0.65870602,  0.41596221,  0.63750406,  0.41408691,  0.2727934 ,
#         0.37314161,  0.16665834,  0.36920153,  0.24269208,  0.27775633,
#         0.48491042,  0.46485588,  0.62104938,  0.25095793,  0.47491615,
#         0.93238083,  0.58189206,  0.14558085,  0.3546317 ,  0.94844043,
#         0.77348238,  0.7230289 ,  0.31258349,  0.1478927 ,  0.59407818,
#         0.62731514,  0.59777571,  0.63133331,  0.71729441,  0.62497051,
#         0.08282606,  0.33220345,  0.45156228,  0.21298997,  0.51173962,
#         0.75307375,  0.74394911,  0.85270112,  0.71190259,  0.14521673,
#         0.04654935,  0.39036263,  0.15817213,  0.27110081,  0.43241343,
#         0.39363658,  0.57529127,  0.21657804,  0.67047179,  0.25009996,
#         0.71491671,  0.96954504,  0.36616495,  0.29682108,  0.75692845,
#         0.4324336 ,  0.22189426,  0.30865359,  0.79356851,  0.28310496,
#         0.74381799,  0.51376727,  0.56014518,  0.41038864,  0.44648716,
#         0.42536032,  0.40547501,  0.30090134,  0.52945511,  0.44043496,
#         0.56875169,  0.17108993,  0.62666085,  0.27453029,  0.60606445,
#         0.72673462,  0.52971252,  0.49676005,  0.54651862,  0.51752454,
#         0.72245494,  0.28302135,  0.37111264,  0.58671795,  0.46888896,
#         0.64899865,  0.68514868,  0.62849621,  0.35048266,  0.73794602,
#         0.36191446,  0.45125113,  0.22334547,  0.86207344,  0.66544153,
#         0.45527878,  0.40403194,  0.68241654,  0.63552196,  0.69522811,
#         0.33590299,  0.14150617,  0.27364798,  0.53478041,  0.65652104,
#         0.50985788,  0.29188263,  0.50253349,  0.6000469 ,  0.34107754,
#         0.34810986,  0.40120132,  0.19244958, -0.0958999 ,  0.40295971])

# %%
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Other Distribuiton
# ## Log Normal Distribution,Power Law Distribution

# %%
mu, sigma = 3., 1. # mean and standard deviation
s = np.random.lognormal(mu, sigma, 1000)

# %%
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# When applied log we get Normal distribution

# %%
sns.histplot(np.log(s),kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Check whether Disstribution is Normal Distribution

# %% [markdown]
# #### If you want to check whether feature is guassian or normal distributed
# #### Q-Q plot

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %% [markdown]
# ### create a normal distributed data

# %%
s=np.random.normal(0.5,0.2,1000)
plot_data(s)

# %% [markdown]
# ### Check with `sepal_width`

# %%
plot_data(df['sepal_width'])

# %% [markdown]
# ### Check Log normal distribution

# %%
mu, sigma = 3., 1. # mean and standard deviation
sample = np.random.lognormal(mu, sigma, 100)

# %%
def plot_data_log(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(np.log(sample),dist='norm',plot=pylab)
    plt.show()

# %%
plot_data_log(sample)

# %% [markdown]
# ## Pearson and Sperman Rank Correlation

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

# %%
df_numeric = pd.get_dummies(df)

# %%
correlation_matrix = df_numeric.corr()
correlation_matrix
# Out:
#              total_bill       tip      size  sex_Male  sex_Female  smoker_Yes  \
# total_bill     1.000000  0.675734  0.598315  0.144877   -0.144877    0.085721
# tip            0.675734  1.000000  0.489299  0.088862   -0.088862    0.005929
# size           0.598315  0.489299  1.000000  0.086195   -0.086195   -0.133178
# sex_Male       0.144877  0.088862  0.086195  1.000000   -1.000000    0.002816
# sex_Female    -0.144877 -0.088862 -0.086195 -1.000000    1.000000   -0.002816
# smoker_Yes     0.085721  0.005929 -0.133178  0.002816   -0.002816    1.000000
# smoker_No     -0.085721 -0.005929  0.133178 -0.002816    0.002816   -1.000000
# day_Thur      -0.138174 -0.095879 -0.072598 -0.194445    0.194445   -0.128534
# day_Fri       -0.086168 -0.055463 -0.142184 -0.071060    0.071060    0.244316
# day_Sat        0.054919 -0.002790 -0.041121  0.053957   -0.053957    0.155744
# day_Sun        0.122953  0.125114  0.193054  0.168106   -0.168106   -0.181624
# time_Lunch    -0.183118 -0.121629 -0.103411 -0.205231    0.205231   -0.054921
# time_Dinner    0.183118  0.121629  0.103411  0.205231   -0.205231    0.054921
#
#              smoker_No  day_Thur   day_Fri   day_Sat   day_Sun  time_Lunch  \
# total_bill   -0.085721 -0.138174 -0.086168  0.054919  0.122953   -0.183118
# tip          -0.005929 -0.095879 -0.055463 -0.002790  0.125114   -0.121629
# size          0.133178 -0.072598 -0.142184 -0.041121  0.193054   -0.103411
# sex_Male     -0.002816 -0.194445 -0.071060  0.053957  0.168106   -0.205231
# sex_Female    0.002816  0.194445  0.071060 -0.053957 -0.168106    0.205231
# smoker_Yes   -1.000000 -0.128534  0.244316  0.155744 -0.181624   -0.054921
# smoker_No     1.000000  0.128534 -0.244316 -0.155744  0.181624    0.054921
# day_Thur      0.128534  1.000000 -0.169608 -0.434480 -0.392566    0.917996
# day_Fri      -0.244316 -0.169608  1.000000 -0.216319 -0.195451    0.058159
# day_Sat      -0.155744 -0.434480 -0.216319  1.000000 -0.500682   -0.462709
# day_Sun       0.181624 -0.392566 -0.195451 -0.500682  1.000000   -0.418071
# time_Lunch    0.054921  0.917996  0.058159 -0.462709 -0.418071    1.000000
# time_Dinner  -0.054921 -0.917996 -0.058159  0.462709  0.418071   -1.000000
#
#              time_Dinner
# total_bill      0.183118
# tip             0.121629
# size            0.103411
# sex_Male        0.205231
# sex_Female     -0.205231
# smoker_Yes      0.054921
# smoker_No      -0.054921
# day_Thur       -0.917996
# day_Fri        -0.058159
# day_Sat         0.462709
# day_Sun         0.418071
# time_Lunch     -1.000000
# time_Dinner     1.000000

# %%
sns.pairplot(correlation_matrix)
plt.show()
# Out:
# C:\Users\udaya\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(correlation_matrix.iloc[:3, :].T)  # Transpose the matrix to have variables as rows
plt.show()
# Out:
# C:\Users\udaya\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
